# %%
import numpy as np

# %%
import pandas as pd

# %%
data = {
"employee": ["Alice", "Bob", "Charlie", "Diana", "Evan"],
"department": ["IT", "HR", "IT", "Finance", "HR"],
"salary": [70000, 50000, 80000, 65000, 52000],
"years_exp": [5, 2, 7, 4, 3]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   employee department  salary  years_exp
# 0    Alice         IT   70000          5
# 1      Bob         HR   50000          2
# 2  Charlie         IT   80000          7
# 3    Diana    Finance   65000          4
# 4     Evan         HR   52000          3

# %%
df[["employee", "salary"]]
# Out:
#   employee  salary
# 0    Alice   70000
# 1      Bob   50000
# 2  Charlie   80000
# 3    Diana   65000
# 4     Evan   52000

# %%
df[df["salary"] > 60000]
# Out:
#   employee department  salary  years_exp
# 0    Alice         IT   70000          5
# 2  Charlie         IT   80000          7
# 3    Diana    Finance   65000          4

# %%
df["salary_k"] = df["salary"] / 1000

# %%
df["seniority"] = np.where(df["years_exp"] >= 5, "Senior", "Junior")

# %%
df.sort_values(by="salary", ascending=False)
# Out:
#   employee department  salary  years_exp  salary_k seniority
# 2  Charlie         IT   80000          7      80.0    Senior
# 0    Alice         IT   70000          5      70.0    Senior
# 3    Diana    Finance   65000          4      65.0    Junior
# 4     Evan         HR   52000          3      52.0    Junior
# 1      Bob         HR   50000          2      50.0    Junior

# %%
df.describe()
# Out:
#              salary  years_exp   salary_k
# count      5.000000   5.000000   5.000000
# mean   63400.000000   4.200000  63.400000
# std    12561.846998   1.923538  12.561847
# min    50000.000000   2.000000  50.000000
# 25%    52000.000000   3.000000  52.000000
# 50%    65000.000000   4.000000  65.000000
# 75%    70000.000000   5.000000  70.000000
# max    80000.000000   7.000000  80.000000

# %%
df["salary_per_year_exp"] = df["salary"] / df["years_exp"]

# %%
df.sort_values("salary_per_year_exp", ascending=False).head(1)
# Out:
#   employee department  salary  years_exp  salary_k seniority  \
# 1      Bob         HR   50000          2      50.0    Junior
#
#    salary_per_year_exp
# 1              25000.0

# %%
df.groupby("department")["salary"].mean()
# Out:
# department
# Finance    65000.0
# HR         51000.0
# IT         75000.0
# Name: salary, dtype: float64

# %%
df.groupby("department").agg(
avg_salary=("salary", "mean"),
max_exp=("years_exp", "max"),
count=("employee", "count")
)
# Out:
#             avg_salary  max_exp  count
# department
# Finance        65000.0        4      1
# HR             51000.0        3      2
# IT             75000.0        7      2

# %%
df["dept_avg_salary"] = df.groupby("department")["salary"].transform("mean")

# %%
df
# Out:
#   employee department  salary  years_exp  salary_k seniority  \
# 0    Alice         IT   70000          5      70.0    Senior
# 1      Bob         HR   50000          2      50.0    Junior
# 2  Charlie         IT   80000          7      80.0    Senior
# 3    Diana    Finance   65000          4      65.0    Junior
# 4     Evan         HR   52000          3      52.0    Junior
#
#    salary_per_year_exp  dept_avg_salary
# 0         14000.000000          75000.0
# 1         25000.000000          51000.0
# 2         11428.571429          75000.0
# 3         16250.000000          65000.0
# 4         17333.333333          51000.0

# %%
df["salary_diff"] = df["salary"] - df["dept_avg_salary"]
df[["employee", "department", "salary_diff"]]
# Out:
#   employee department  salary_diff
# 0    Alice         IT      -5000.0
# 1      Bob         HR      -1000.0
# 2  Charlie         IT       5000.0
# 3    Diana    Finance          0.0
# 4     Evan         HR       1000.0

# %%
departments = pd.DataFrame({
"department": ["IT", "HR", "Finance"],
"manager": ["Grace", "Helen", "Ian"]
})

# %%
pd.merge(df, departments, on="department", how="inner")
# Out:
#   employee department  salary  years_exp  salary_k seniority  \
# 0    Alice         IT   70000          5      70.0    Senior
# 1      Bob         HR   50000          2      50.0    Junior
# 2  Charlie         IT   80000          7      80.0    Senior
# 3    Diana    Finance   65000          4      65.0    Junior
# 4     Evan         HR   52000          3      52.0    Junior
#
#    salary_per_year_exp  dept_avg_salary  salary_diff manager
# 0         14000.000000          75000.0      -5000.0   Grace
# 1         25000.000000          51000.0      -1000.0   Helen
# 2         11428.571429          75000.0       5000.0   Grace
# 3         16250.000000          65000.0          0.0     Ian
# 4         17333.333333          51000.0       1000.0   Helen

# %%
pd.merge(df, departments, on="department", how="left")
# Out:
#   employee department  salary  years_exp  salary_k seniority  \
# 0    Alice         IT   70000          5      70.0    Senior
# 1      Bob         HR   50000          2      50.0    Junior
# 2  Charlie         IT   80000          7      80.0    Senior
# 3    Diana    Finance   65000          4      65.0    Junior
# 4     Evan         HR   52000          3      52.0    Junior
#
#    salary_per_year_exp  dept_avg_salary  salary_diff manager
# 0         14000.000000          75000.0      -5000.0   Grace
# 1         25000.000000          51000.0      -1000.0   Helen
# 2         11428.571429          75000.0       5000.0   Grace
# 3         16250.000000          65000.0          0.0     Ian
# 4         17333.333333          51000.0       1000.0   Helen

# %%
df_indexed = df.set_index("department")
dep_indexed = departments.set_index("department")

# %%
df_indexed.join(dep_indexed)
# Out:
#            employee  salary  years_exp  salary_k seniority  \
# department
# IT            Alice   70000          5      70.0    Senior
# HR              Bob   50000          2      50.0    Junior
# IT          Charlie   80000          7      80.0    Senior
# Finance       Diana   65000          4      65.0    Junior
# HR             Evan   52000          3      52.0    Junior
#
#             salary_per_year_exp  dept_avg_salary  salary_diff manager
# department
# IT                 14000.000000          75000.0      -5000.0   Grace
# HR                 25000.000000          51000.0      -1000.0   Helen
# IT                 11428.571429          75000.0       5000.0   Grace
# Finance            16250.000000          65000.0          0.0     Ian
# HR                 17333.333333          51000.0       1000.0   Helen

# %%
enriched = pd.merge(df, departments, on="department", how="left")
enriched[["employee", "department", "manager"]]
# Out:
#   employee department manager
# 0    Alice         IT   Grace
# 1      Bob         HR   Helen
# 2  Charlie         IT   Grace
# 3    Diana    Finance     Ian
# 4     Evan         HR   Helen

# %%
df.isna().sum()
df.fillna(0)
df.dropna()
# Out:
#   employee department  salary  years_exp  salary_k seniority  \
# 0    Alice         IT   70000          5      70.0    Senior
# 1      Bob         HR   50000          2      50.0    Junior
# 2  Charlie         IT   80000          7      80.0    Senior
# 3    Diana    Finance   65000          4      65.0    Junior
# 4     Evan         HR   52000          3      52.0    Junior
#
#    salary_per_year_exp  dept_avg_salary  salary_diff
# 0         14000.000000          75000.0      -5000.0
# 1         25000.000000          51000.0      -1000.0
# 2         11428.571429          75000.0       5000.0
# 3         16250.000000          65000.0          0.0
# 4         17333.333333          51000.0       1000.0

# %%
df.to_csv("employees_raw.csv", index=False)

# %%
raw_df = pd.read_csv("employees_raw.csv")

# %%
raw_df.columns = raw_df.columns.str.lower().str.strip()

# %%
raw_df = raw_df.drop_duplicates()

# %%
raw_df["salary"] = raw_df["salary"].fillna(raw_df["salary"].median())

# %%
raw_df["salary_k"] = raw_df["salary"] / 1000

# %%
summary = (
  raw_df
  .groupby("department")
  .agg(
avg_salary=("salary", "mean"),
headcount=("employee", "count")
)
.reset_index()
)

# %%
raw_df.to_csv("employees_clean.csv", index=False)
summary.to_csv("department_summary.csv", index=False)
